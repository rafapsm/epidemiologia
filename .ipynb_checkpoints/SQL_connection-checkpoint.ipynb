# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Requirement already satisfied: ipython-sql in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (0.3.9)',
#  'Requirement already satisfied: prettytable in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (0.7.2)',
#  'Requirement already satisfied: six in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (1.14.0)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (0.2.0)',
#  'Requirement already satisfied: sqlparse in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (0.3.1)',
#  'Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (1.3.16)',
#  'Requirement already satisfied: ipython>=1.0 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (7.13.0)',
#  'Requirement already satisfied: jedi>=0.10 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.15.2)',
#  'Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)',
#  'Requirement already satisfied: traitlets>=4.2 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.3.3)',
#  'Requirement already satisfied: pickleshare in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)',
#  'Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (3.0.4)',
#  'Requirement already satisfied: pygments in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (2.6.1)',
#  'Requirement already satisfied: backcall in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)',
#  'Requirement already satisfied: setuptools>=18.5 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (46.1.3.post20200330)',
#  'Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)',
#  'Requirement already satisfied: decorator in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)',
#  'Requirement already satisfied: parso>=0.5.2 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.5.2)',
#  'Requirement already satisfied: wcwidth in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.1.9)',
#  'Requirement already satisfied: ptyprocess>=0.5 in /Users/rafaelamachado/opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)']

# %%
# %load_ext sql

# %%
import psycopg2
import sys
if sys.version[0] == '2':
    reload(sys)
    sys.setdefaultencoding("utf-8")

# %%
hostname = 'localhost'
username = 'postgres'
password = '27rafa1998'
database = 'sig'

# %%
def doQuery( conn ) :
    cur = conn.cursor()
    cur.execute( "SELECT name_long FROM countries" )
    for concelho in cur.fetchall() :
        print (concelho)

myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
doQuery( myConnection )
# Out:
# ('Indonesia',)
# ('Malaysia',)
# ('Chile',)
# ('Bolivia',)
# ('Peru',)
# ('Argentina',)
# ('Dhekelia',)
# ('Kenya',)
# ('Cyprus',)
# ('India',)
# ('China',)
# ('Pakistan',)
# ('Israel',)
# ('Libya',)
# ('Palestine',)
# ('Malawi',)
# ('Tanzania',)
# ('Syria',)
# ('Guyana',)
# ('Republic of Korea',)
# ('Lebanon',)
# ('Ethiopia',)
# ('South Sudan',)
# ('Somalia',)
# ('Somaliland',)
# ('France',)
# ('Suriname',)
# ('Dem. Rep. Korea',)
# ('Morocco',)
# ('Western Sahara',)
# ('Costa Rica',)
# ('Nicaragua',)
# ('Republic of the Congo',)
# ('Democratic Republic of the Congo',)
# ('Namibia',)
# ('South Africa',)
# ('Saint-Martin',)
# ('Sint Maarten',)
# ('Oman',)
# ('Bhutan',)
# ('Ukraine',)
# ('Belarus',)
# ('Uzbekistan',)
# ('Kazakhstan',)
# ('Tajikistan',)
# ('Lithuania',)
# ('Brazil',)
# ('Uruguay',)
# ('Mongolia',)
# ('Russian Federation',)
# ('Czech Republic',)
# ('Ghana',)
# ('Germany',)
# ('Estonia',)
# ('Latvia',)
# ('Norway',)
# ('Sweden',)
# ('Finland',)
# ('Vietnam',)
# ('Cambodia',)
# ('Azerbaijan',)
# ('Tunisia',)
# ('Luxembourg',)
# ('United Arab Emirates',)
# ('Belgium',)
# ('Georgia',)
# ('Kyrgyzstan',)
# ('Mali',)
# ('Macedonia',)
# ('Albania',)
# ('Kosovo',)
# ('Turkey',)
# ('Spain',)
# ('Lao PDR',)
# ('Denmark',)
# ('Armenia',)
# ('Romania',)
# ('Hungary',)
# ('Slovakia',)
# ('Poland',)
# ('Ireland',)
# ('United Kingdom',)
# ('Greece',)
# ('Zambia',)
# ('Sierra Leone',)
# ('Guinea',)
# ('Liberia',)
# ('Central African Republic',)
# ('Sudan',)
# ('Djibouti',)
# ('Eritrea',)
# ('Austria',)
# ('Iraq',)
# ('Italy',)
# ('Switzerland',)
# ('Iran',)
# ('Netherlands',)
# ('Liechtenstein',)
# ("Côte d'Ivoire",)
# ('Serbia',)
# ('Senegal',)
# ('Nigeria',)
# ('Benin',)
# ('Angola',)
# ('Croatia',)
# ('Slovenia',)
# ('Qatar',)
# ('Saudi Arabia',)
# ('Botswana',)
# ('Zimbabwe',)
# ('Bulgaria',)
# ('Thailand',)
# ('San Marino',)
# ('Monaco',)
# ('Algeria',)
# ('Mozambique',)
# ('Haiti',)
# ('Afghanistan',)
# ('Dominican Republic',)
# ('Chad',)
# ('Uganda',)
# ('Kuwait',)
# ('eSwatini',)
# ('Turkmenistan',)
# ('El Salvador',)
# ('Guatemala',)
# ('Timor-Leste',)
# ('Brunei Darussalam',)
# ('Burundi',)
# ('Andorra',)
# ('Niger',)
# ('Rwanda',)
# ('Myanmar',)
# ('Bangladesh',)
# ('Montenegro',)
# ('Bosnia and Herzegovina',)
# ('US Naval Base Guantanamo Bay',)
# ('Cuba',)
# ('Honduras',)
# ('Ecuador',)
# ('Colombia',)
# ('Paraguay',)
# ('Portugal',)
# ('Moldova',)
# ('Jordan',)
# ('Nepal',)
# ('Burkina Faso',)
# ('Lesotho',)
# ('Cameroon',)
# ('Gabon',)
# ('Togo',)
# ('Guinea-Bissau',)
# ('Gibraltar',)
# ('United States',)
# ('Canada',)
# ('Mexico',)
# ('Papua New Guinea',)
# ('Egypt',)
# ('Yemen',)
# ('Mauritania',)
# ('Belize',)
# ('Panama',)
# ('Venezuela',)
# ('Equatorial Guinea',)
# ('Hong Kong',)
# ('The Gambia',)
# ('Antarctica',)
# ('Vatican',)
# ('Northern Cyprus',)
# ('Baikonur Cosmodrome',)
# ('Australia',)
# ('Cyprus U.N. Buffer Zone',)
# ('Siachen Glacier',)
# ('Akrotiri',)
# ('Greenland',)
# ('Fiji',)
# ('New Zealand',)
# ('New Caledonia',)
# ('Madagascar',)
# ('Philippines',)
# ('Curaçao',)
# ('Aruba',)
# ('Sri Lanka',)
# ('Bahamas',)
# ('Turks and Caicos Islands',)
# ('Saint Pierre and Miquelon',)
# ('Iceland',)
# ('Ashmore and Cartier Islands',)
# ('Taiwan',)
# ('Japan',)
# ('Anguilla',)
# ('Pitcairn Islands',)
# ('French Polynesia',)
# ('French Southern and Antarctic Lands',)
# ('Seychelles',)
# ('Bajo Nuevo Bank (Petrel Islands)',)
# ('Kiribati',)
# ('Marshall Islands',)
# ('Trinidad and Tobago',)
# ('Grenada',)
# ('Saint Vincent and the Grenadines',)
# ('Barbados',)
# ('Saint Lucia',)
# ('Dominica',)
# ('Serranilla Bank',)
# ('United States Minor Outlying Islands',)
# ('Montserrat',)
# ('Antigua and Barbuda',)
# ('Saint Kitts and Nevis',)
# ('United States Virgin Islands',)
# ('Saint-Barthélemy',)
# ('Puerto Rico',)
# ('British Virgin Islands',)
# ('Jamaica',)
# ('Malta',)
# ('Cayman Islands',)
# ('Bermuda',)
# ('Heard I. and McDonald Islands',)
# ('Jersey',)
# ('Saint Helena',)
# ('Mauritius',)
# ('Comoros',)
# ('Guernsey',)
# ('São Tomé and Principe',)
# ('Republic of Cabo Verde',)
# ('Niue',)
# ('Isle of Man',)
# ('Åland Islands',)
# ('Clipperton Island',)
# ('Faeroe Islands',)
# ('Indian Ocean Territories',)
# ('Scarborough Reef',)
# ('British Indian Ocean Territory',)
# ('Singapore',)
# ('Norfolk Island',)
# ('Cook Islands',)
# ('Tonga',)
# ('Wallis and Futuna Islands',)
# ('Samoa',)
# ('Solomon Islands',)
# ('Tuvalu',)
# ('Maldives',)
# ('Nauru',)
# ('Federated States of Micronesia',)
# ('South Georgia and the Islands',)
# ('Falkland Islands',)
# ('Vanuatu',)
# ('American Samoa',)
# ('Palau',)
# ('Guam',)
# ('Macao',)
# ('Northern Mariana Islands',)
# ('Bahrain',)
# ('Coral Sea Islands',)
# ('Spratly Islands',)

# %%
#create_engine("postgresql://postgres:27rafa1998@localhos/sig")
import os
user = os.getenv('user')
password = os.getenv('pass')
connection_string = "postgresql://postgres:27rafa1998@localhost/sig".format(user=user, password=password)

# %sql $connection_string
# Out:
# 'Connected: postgres@sig'

# %%
# %sql select name_long from "countries"
# Out:
#  * postgresql://postgres:***@localhost/sig
# 255 rows affected.
# [('Indonesia',),
#  ('Malaysia',),
#  ('Chile',),
#  ('Bolivia',),
#  ('Peru',),
#  ('Argentina',),
#  ('Dhekelia',),
#  ('Kenya',),
#  ('Cyprus',),
#  ('India',),
#  ('China',),
#  ('Pakistan',),
#  ('Israel',),
#  ('Libya',),
#  ('Palestine',),
#  ('Malawi',),
#  ('Tanzania',),
#  ('Syria',),
#  ('Guyana',),
#  ('Republic of Korea',),
#  ('Lebanon',),
#  ('Ethiopia',),
#  ('South Sudan',),
#  ('Somalia',),
#  ('Somaliland',),
#  ('France',),
#  ('Suriname',),
#  ('Dem. Rep. Korea',),
#  ('Morocco',),
#  ('Western Sahara',),
#  ('Costa Rica',),
#  ('Nicaragua',),
#  ('Republic of the Congo',),
#  ('Democratic Republic of the Congo',),
#  ('Namibia',),
#  ('South Africa',),
#  ('Saint-Martin',),
#  ('Sint Maarten',),
#  ('Oman',),
#  ('Bhutan',),
#  ('Ukraine',),
#  ('Belarus',),
#  ('Uzbekistan',),
#  ('Kazakhstan',),
#  ('Tajikistan',),
#  ('Lithuania',),
#  ('Brazil',),
#  ('Uruguay',),
#  ('Mongolia',),
#  ('Russian Federation',),
#  ('Czech Republic',),
#  ('Ghana',),
#  ('Germany',),
#  ('Estonia',),
#  ('Latvia',),
#  ('Norway',),
#  ('Sweden',),
#  ('Finland',),
#  ('Vietnam',),
#  ('Cambodia',),
#  ('Azerbaijan',),
#  ('Tunisia',),
#  ('Luxembourg',),
#  ('United Arab Emirates',),
#  ('Belgium',),
#  ('Georgia',),
#  ('Kyrgyzstan',),
#  ('Mali',),
#  ('Macedonia',),
#  ('Albania',),
#  ('Kosovo',),
#  ('Turkey',),
#  ('Spain',),
#  ('Lao PDR',),
#  ('Denmark',),
#  ('Armenia',),
#  ('Romania',),
#  ('Hungary',),
#  ('Slovakia',),
#  ('Poland',),
#  ('Ireland',),
#  ('United Kingdom',),
#  ('Greece',),
#  ('Zambia',),
#  ('Sierra Leone',),
#  ('Guinea',),
#  ('Liberia',),
#  ('Central African Republic',),
#  ('Sudan',),
#  ('Djibouti',),
#  ('Eritrea',),
#  ('Austria',),
#  ('Iraq',),
#  ('Italy',),
#  ('Switzerland',),
#  ('Iran',),
#  ('Netherlands',),
#  ('Liechtenstein',),
#  ("Côte d'Ivoire",),
#  ('Serbia',),
#  ('Senegal',),
#  ('Nigeria',),
#  ('Benin',),
#  ('Angola',),
#  ('Croatia',),
#  ('Slovenia',),
#  ('Qatar',),
#  ('Saudi Arabia',),
#  ('Botswana',),
#  ('Zimbabwe',),
#  ('Bulgaria',),
#  ('Thailand',),
#  ('San Marino',),
#  ('Monaco',),
#  ('Algeria',),
#  ('Mozambique',),
#  ('Haiti',),
#  ('Afghanistan',),
#  ('Dominican Republic',),
#  ('Chad',),
#  ('Uganda',),
#  ('Kuwait',),
#  ('eSwatini',),
#  ('Turkmenistan',),
#  ('El Salvador',),
#  ('Guatemala',),
#  ('Timor-Leste',),
#  ('Brunei Darussalam',),
#  ('Burundi',),
#  ('Andorra',),
#  ('Niger',),
#  ('Rwanda',),
#  ('Myanmar',),
#  ('Bangladesh',),
#  ('Montenegro',),
#  ('Bosnia and Herzegovina',),
#  ('US Naval Base Guantanamo Bay',),
#  ('Cuba',),
#  ('Honduras',),
#  ('Ecuador',),
#  ('Colombia',),
#  ('Paraguay',),
#  ('Portugal',),
#  ('Moldova',),
#  ('Jordan',),
#  ('Nepal',),
#  ('Burkina Faso',),
#  ('Lesotho',),
#  ('Cameroon',),
#  ('Gabon',),
#  ('Togo',),
#  ('Guinea-Bissau',),
#  ('Gibraltar',),
#  ('United States',),
#  ('Canada',),
#  ('Mexico',),
#  ('Papua New Guinea',),
#  ('Egypt',),
#  ('Yemen',),
#  ('Mauritania',),
#  ('Belize',),
#  ('Panama',),
#  ('Venezuela',),
#  ('Equatorial Guinea',),
#  ('Hong Kong',),
#  ('The Gambia',),
#  ('Antarctica',),
#  ('Vatican',),
#  ('Northern Cyprus',),
#  ('Baikonur Cosmodrome',),
#  ('Australia',),
#  ('Cyprus U.N. Buffer Zone',),
#  ('Siachen Glacier',),
#  ('Akrotiri',),
#  ('Greenland',),
#  ('Fiji',),
#  ('New Zealand',),
#  ('New Caledonia',),
#  ('Madagascar',),
#  ('Philippines',),
#  ('Curaçao',),
#  ('Aruba',),
#  ('Sri Lanka',),
#  ('Bahamas',),
#  ('Turks and Caicos Islands',),
#  ('Saint Pierre and Miquelon',),
#  ('Iceland',),
#  ('Ashmore and Cartier Islands',),
#  ('Taiwan',),
#  ('Japan',),
#  ('Anguilla',),
#  ('Pitcairn Islands',),
#  ('French Polynesia',),
#  ('French Southern and Antarctic Lands',),
#  ('Seychelles',),
#  ('Bajo Nuevo Bank (Petrel Islands)',),
#  ('Kiribati',),
#  ('Marshall Islands',),
#  ('Trinidad and Tobago',),
#  ('Grenada',),
#  ('Saint Vincent and the Grenadines',),
#  ('Barbados',),
#  ('Saint Lucia',),
#  ('Dominica',),
#  ('Serranilla Bank',),
#  ('United States Minor Outlying Islands',),
#  ('Montserrat',),
#  ('Antigua and Barbuda',),
#  ('Saint Kitts and Nevis',),
#  ('United States Virgin Islands',),
#  ('Saint-Barthélemy',),
#  ('Puerto Rico',),
#  ('British Virgin Islands',),
#  ('Jamaica',),
#  ('Malta',),
#  ('Cayman Islands',),
#  ('Bermuda',),
#  ('Heard I. and McDonald Islands',),
#  ('Jersey',),
#  ('Saint Helena',),
#  ('Mauritius',),
#  ('Comoros',),
#  ('Guernsey',),
#  ('São Tomé and Principe',),
#  ('Republic of Cabo Verde',),
#  ('Niue',),
#  ('Isle of Man',),
#  ('Åland Islands',),
#  ('Clipperton Island',),
#  ('Faeroe Islands',),
#  ('Indian Ocean Territories',),
#  ('Scarborough Reef',),
#  ('British Indian Ocean Territory',),
#  ('Singapore',),
#  ('Norfolk Island',),
#  ('Cook Islands',),
#  ('Tonga',),
#  ('Wallis and Futuna Islands',),
#  ('Samoa',),
#  ('Solomon Islands',),
#  ('Tuvalu',),
#  ('Maldives',),
#  ('Nauru',),
#  ('Federated States of Micronesia',),
#  ('South Georgia and the Islands',),
#  ('Falkland Islands',),
#  ('Vanuatu',),
#  ('American Samoa',),
#  ('Palau',),
#  ('Guam',),
#  ('Macao',),
#  ('Northern Mariana Islands',),
#  ('Bahrain',),
#  ('Coral Sea Islands',),
#  ('Spratly Islands',)]

# %%
# %sql select concelho from "Portugal"
# Out:
#  * postgresql://postgres:***@localhost/sig
# 3223 rows affected.
# [('FARO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('VILA DO BISPO',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('OLHÃO',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('VILA DO BISPO',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('VILA DE REI',),
#  ('SABUGAL',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('FARO',),
#  ('OLHÃO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('MÉRTOLA',),
#  ('CASCAIS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('OLHÃO',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOA',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('CRATO',),
#  ('LAGOS',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOA',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('BOMBARRAL',),
#  ('PORTALEGRE',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('ALMODÔVAR',),
#  ('MÉRTOLA',),
#  ('ALMODÔVAR',),
#  ('ODEMIRA',),
#  ('ODEMIRA',),
#  ('MÉRTOLA',),
#  ('CASTRO VERDE',),
#  ('ODEMIRA',),
#  ('MÉRTOLA',),
#  ('ODEMIRA',),
#  ('ODEMIRA',),
#  ('OURIQUE',),
#  ('ODEMIRA',),
#  ('OURIQUE',),
#  ('ODEMIRA',),
#  ('MÉRTOLA',),
#  ('MÉRTOLA',),
#  ('CASTRO VERDE',),
#  ('CASTRO VERDE',),
#  ('ODEMIRA',),
#  ('CASTRO VERDE',),
#  ('ODEMIRA',),
#  ('SINES',),
#  ('MÉRTOLA',),
#  ('OURIQUE',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('AMADORA',),
#  ('LISBOA',),
#  ('BOMBARRAL',),
#  ('GOLEGÃ',),
#  ('ÓBIDOS',),
#  ('PONTE DE SOR',),
#  ('SANTARÉM',),
#  ('ÓBIDOS',),
#  ('RIO MAIOR',),
#  ('PORTALEGRE',),
#  ('ÓBIDOS',),
#  ('LISBOA',),
#  ('ÉVORA',),
#  ('PENICHE',),
#  ('PENICHE',),
#  ('PENICHE',),
#  ('CRATO',),
#  ('SANTARÉM',),
#  ('SANTARÉM',),
#  ('PENACOVA',),
#  ('SINTRA',),
#  ('PONTE DE SOR',),
#  ('CHAMUSCA',),
#  ('PORTALEGRE',),
#  ('CRATO',),
#  ('PORTO DE MÓS',),
#  ('ALCOBAÇA',),
#  ('OURÉM',),
#  ('NISA',),
#  ('OURÉM',),
#  ('MAÇÃO',),
#  ('BATALHA',),
#  ('MAÇÃO',),
#  ('OURÉM',),
#  ('TOMAR',),
#  ('BATALHA',),
#  ('BATALHA',),
#  ('TOMAR',),
#  ('BATALHA',),
#  ('TOMAR',),
#  ('OURÉM',),
#  ('AMADORA',),
#  ('CASCAIS',),
#  ('VILA VIÇOSA',),
#  ('ALANDROAL',),
#  ('PROENÇA-A-NOVA',),
#  ('TOMAR',),
#  ('OURÉM',),
#  ('FERREIRA DO ZÊZERE',),
#  ('VILA VELHA DE RÓDÃO',),
#  ('LEIRIA',),
#  ('FERREIRA DO ZÊZERE',),
#  ('LEIRIA',),
#  ('MARINHA GRANDE',),
#  ('LISBOA',),
#  ('SANTARÉM',),
#  ('ALTER DO CHÃO',),
#  ('BOMBARRAL',),
#  ('CALDAS DA RAINHA',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('SEIA',),
#  ('COVILHÃ',),
#  ('SABUGAL',),
#  ('SABUGAL',),
#  ('MEALHADA',),
#  ('FIGUEIRA DA FOZ',),
#  ('PENAMACOR',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('SABUGAL',),
#  ('BELMONTE',),
#  ('AVEIRO',),
#  ('ALMEIDA',),
#  ('TONDELA',),
#  ('ALJEZUR',),
#  ('COVILHÃ',),
#  ('CANTANHEDE',),
#  ('SABUGAL',),
#  ('SEIA',),
#  ('PENACOVA',),
#  ('TÁBUA',),
#  ('PENACOVA',),
#  ('CELORICO DA BEIRA',),
#  ('MONÇÃO',),
#  ('ALMODÔVAR',),
#  ('SABUGAL',),
#  ('ARCOS DE VALDEVEZ',),
#  ('LAGOA',),
#  ('ODEMIRA',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('ALJEZUR',),
#  ('TÁBUA',),
#  ('COIMBRA',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('MONÇÃO',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('MANGUALDE',),
#  ('MANGUALDE',),
#  ('LAGOA',),
#  ('GUARDA',),
#  ('VISEU',),
#  ('ÍLHAVO',),
#  ('GUARDA',),
#  ('CELORICO DA BEIRA',),
#  ('GUARDA',),
#  ('ALMEIDA',),
#  ('LOULÉ',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('GUARDA',),
#  ('GOUVEIA',),
#  ('GUARDA',),
#  ('GUARDA',),
#  ('TONDELA',),
#  ('ÁGUEDA',),
#  ('ÁGUEDA',),
#  ('TONDELA',),
#  ('TONDELA',),
#  ('MANGUALDE',),
#  ('ÁGUEDA',),
#  ('TONDELA',),
#  ('CELORICO DA BEIRA',),
#  ('ARCOS DE VALDEVEZ',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LAGOA',),
#  ('VALENÇA',),
#  ('MONÇÃO',),
#  ('VINHAIS',),
#  ('ARCOS DE VALDEVEZ',),
#  ('BRAGANÇA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LOULÉ',),
#  ('VALENÇA',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('VALENÇA',),
#  ('VALENÇA',),
#  ('TAVIRA',),
#  ('ODEMIRA',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('ALJEZUR',),
#  ('VALENÇA',),
#  ('VALENÇA',),
#  ('SINES',),
#  ('SANTIAGO DO CACÉM',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MELGAÇO',),
#  ('LAGOA',),
#  ('LAGOA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('VALENÇA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('LAGOA',),
#  ('VILA DO BISPO',),
#  ('ALJEZUR',),
#  ('TAVIRA',),
#  ('LOULÉ',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('OLHÃO',),
#  ('SILVES',),
#  ('LAGOA',),
#  ('FARO',),
#  ('VILA DO BISPO',),
#  ('ALBUFEIRA',),
#  ('FARO',),
#  ('LAGOA',),
#  ('ALBUFEIRA',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('VILA DO BISPO',),
#  ('ALJEZUR',),
#  ('VILA DO BISPO',),
#  ('PORTIMÃO',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJUSTREL',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LOULÉ',),
#  ('LOULÉ',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('VILA REAL DE SANTO ANTÓNIO',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LAGOS',),
#  ('SILVES',),
#  ('SILVES',),
#  ('CASTRO MARIM',),
#  ('VILA REAL DE SANTO ANTÓNIO',),
#  ('ALBUFEIRA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LAGOS',),
#  ('PORTIMÃO',),
#  ('ALJEZUR',),
#  ('VILA REAL DE SANTO ANTÓNIO',),
#  ('TAVIRA',),
#  ('SÃO BRÁS DE ALPORTEL',),
#  ('TAVIRA',),
#  ('ALJEZUR',),
#  ('CASTRO MARIM',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('PORTIMÃO',),
#  ('LOULÉ',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('TAVIRA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALMODÔVAR',),
#  ('ALCOUTIM',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('SILVES',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ODEMIRA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('CASTRO MARIM',),
#  ('LOULÉ',),
#  ('LOULÉ',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('SILVES',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('MONCHIQUE',),
#  ('TAVIRA',),
#  ('ALMODÔVAR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('CASTRO MARIM',),
#  ('MONCHIQUE',),
#  ('ALJEZUR',),
#  ('MONCHIQUE',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LOULÉ',),
#  ('ALCOUTIM',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('OURIQUE',),
#  ('ODEMIRA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALMODÔVAR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('SILVES',),
#  ('ALJEZUR',),
#  ('ALCOUTIM',),
#  ('ALCOUTIM',),
#  ('BEJA',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('ALJUSTREL',),
#  ('SINES',),
#  ('SANTIAGO DO CACÉM',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('BEJA',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('ALJUSTREL',),
#  ('SANTIAGO DO CACÉM',),
#  ('BEJA',),
#  ('ALJUSTREL',),
#  ('BEJA',),
#  ('SERPA',),
#  ('SERPA',),
#  ('SINES',),
#  ('BEJA',),
#  ('SERPA',),
#  ('BEJA',),
#  ('SANTIAGO DO CACÉM',),
#  ('SANTIAGO DO CACÉM',),
#  ('BEJA',),
#  ('FERREIRA DO ALENTEJO',),
#  ('SERPA',),
#  ('FERREIRA DO ALENTEJO',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('PORTEL',),
#  ('FIGUEIRA DE CASTELO RODRIGO',),
#  ('BEJA',),
#  ('BEJA',),
#  ('VIDIGUEIRA',),
#  ('GRÂNDOLA',),
#  ('SESIMBRA',),
#  ('BEJA',),
#  ('SANTIAGO DO CACÉM',),
#  ('SERPA',),
#  ('MOURA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('BEJA',),
#  ('BEJA',),
#  ('SANTIAGO DO CACÉM',),
#  ('SANTIAGO DO CACÉM',),
#  ('FERREIRA DO ALENTEJO',),
#  ('MOURA',),
#  ('CUBA',),
#  ('VIDIGUEIRA',),
#  ('GRÂNDOLA',),
#  ('CUBA',),
#  ('FERREIRA DO ALENTEJO',),
#  ('BARRANCOS',),
#  ('VIDIGUEIRA',),
#  ('MOURA',),
#  ('VIDIGUEIRA',),
#  ('PORTEL',),
#  ('CUBA',),
#  ('CUBA',),
#  ('MOURA',),
#  ('GRÂNDOLA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('CUBA',),
#  ('PORTEL',),
#  ('ALVITO',),
#  ('ALVITO',),
#  ('MOURÃO',),
#  ('MOURA',),
#  ('ALCÁCER DO SAL',),
#  ('PORTEL',),
#  ('MOURÃO',),
#  ('PORTEL',),
#  ('VIANA DO ALENTEJO',),
#  ('PORTEL',),
#  ('REGUENGOS DE MONSARAZ',),
#  ('VIANA DO ALENTEJO',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('MOURÃO',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SETÚBAL',),
#  ('VIANA DO ALENTEJO',),
#  ('GRÂNDOLA',),
#  ('REGUENGOS DE MONSARAZ',),
#  ('REGUENGOS DE MONSARAZ',),
#  ('REGUENGOS DE MONSARAZ',),
#  ('ÉVORA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('SESIMBRA',),
#  ('SETÚBAL',),
#  ('ALCÁCER DO SAL',),
#  ('SETÚBAL',),
#  ('ÉVORA',),
#  ('ALCÁCER DO SAL',),
#  ('REDONDO',),
#  ('ALCÁCER DO SAL',),
#  ('SETÚBAL',),
#  ('ÉVORA',),
#  ('SETÚBAL',),
#  ('SESIMBRA',),
#  ('SETÚBAL',),
#  ('SESIMBRA',),
#  ('MONTEMOR-O-NOVO',),
#  ('ÉVORA',),
#  ('SEIXAL',),
#  ('ALANDROAL',),
#  ('MONTEMOR-O-NOVO',),
#  ('PALMELA',),
#  ('ÉVORA',),
#  ('ALANDROAL',),
#  ('ÉVORA',),
#  ('ÉVORA',),
#  ('CASCAIS',),
#  ('SETÚBAL',),
#  ('SEIXAL',),
#  ('BARREIRO',),
#  ('PALMELA',),
#  ('BARREIRO',),
#  ('VENDAS NOVAS',),
#  ('ÉVORA',),
#  ('CASCAIS',),
#  ('MONTEMOR-O-NOVO',),
#  ('ÉVORA',),
#  ('MONTEMOR-O-NOVO',),
#  ('SEIXAL',),
#  ('SEIXAL',),
#  ('BARREIRO',),
#  ('ALMADA',),
#  ('ALMADA',),
#  ('ALMADA',),
#  ('MOITA',),
#  ('PALMELA',),
#  ('ALMADA',),
#  ('MOITA',),
#  ('MOITA',),
#  ('ALANDROAL',),
#  ('BORBA',),
#  ('ARRAIOLOS',),
#  ('VILA VIÇOSA',),
#  ('SINTRA',),
#  ('ESTREMOZ',),
#  ('LOURES',),
#  ('MONTEMOR-O-NOVO',),
#  ('LOURES',),
#  ('ELVAS',),
#  ('ALMADA',),
#  ('BARREIRO',),
#  ('MOITA',),
#  ('ÉVORA',),
#  ('ÉVORA',),
#  ('MONTIJO',),
#  ('CASCAIS',),
#  ('MONTIJO',),
#  ('BENAVENTE',),
#  ('MAFRA',),
#  ('ESTREMOZ',),
#  ('CORUCHE',),
#  ('MAFRA',),
#  ('MAFRA',),
#  ('MAFRA',),
#  ('MONFORTE',),
#  ('MORA',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('OEIRAS',),
#  ('MONTIJO',),
#  ('LISBOA',),
#  ('SOUSEL',),
#  ('VILA FRANCA DE XIRA',),
#  ('SOUSEL',),
#  ('MAFRA',),
#  ('MORA',),
#  ('ELVAS',),
#  ('MAFRA',),
#  ('ARRUDA DOS VINHOS',),
#  ('BENAVENTE',),
#  ('VILA FRANCA DE XIRA',),
#  ('MAFRA',),
#  ('SOBRAL DE MONTE AGRAÇO',),
#  ('SOBRAL DE MONTE AGRAÇO',),
#  ('ALENQUER',),
#  ('CAMPO MAIOR',),
#  ('TORRES VEDRAS',),
#  ('AVIS',),
#  ('ELVAS',),
#  ('CORUCHE',),
#  ('LISBOA',),
#  ('OEIRAS',),
#  ('ALENQUER',),
#  ('MAFRA',),
#  ('TORRES VEDRAS',),
#  ('SALVATERRA DE MAGOS',),
#  ('SALVATERRA DE MAGOS',),
#  ('AZAMBUJA',),
#  ('ALENQUER',),
#  ('FRONTEIRA',),
#  ('TORRES VEDRAS',),
#  ('TORRES VEDRAS',),
#  ('AVIS',),
#  ('CORUCHE',),
#  ('ALENQUER',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('MONTIJO',),
#  ('SALVATERRA DE MAGOS',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CORUCHE',),
#  ('TORRES VEDRAS',),
#  ('TORRES VEDRAS',),
#  ('CAMPO MAIOR',),
#  ('AVIS',),
#  ('ALENQUER',),
#  ('CAMPO MAIOR',),
#  ('MONFORTE',),
#  ('ALENQUER',),
#  ('AZAMBUJA',),
#  ('AVIS',),
#  ('AZAMBUJA',),
#  ('TORRES VEDRAS',),
#  ('SALVATERRA DE MAGOS',),
#  ('AZAMBUJA',),
#  ('LISBOA',),
#  ('AMADORA',),
#  ('CASCAIS',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('ALENQUER',),
#  ('TORRES VEDRAS',),
#  ('FRONTEIRA',),
#  ('TORRES VEDRAS',),
#  ('CARTAXO',),
#  ('ALENQUER',),
#  ('FRONTEIRA',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('ALCOCHETE',),
#  ('ALCOCHETE',),
#  ('ARRONCHES',),
#  ('LISBOA',),
#  ('PALMELA',),
#  ('OEIRAS',),
#  ('CASCAIS',),
#  ('ALMEIRIM',),
#  ('AVIS',),
#  ('MONFORTE',),
#  ('AZAMBUJA',),
#  ('ALMEIRIM',),
#  ('TORRES VEDRAS',),
#  ('CARTAXO',),
#  ('ALENQUER',),
#  ('CARTAXO',),
#  ('CARTAXO',),
#  ('ALENQUER',),
#  ('ALENQUER',),
#  ('MONFORTE',),
#  ('TORRES VEDRAS',),
#  ('TORRES VEDRAS',),
#  ('CARTAXO',),
#  ('ARRONCHES',),
#  ('ALMEIRIM',),
#  ('CADAVAL',),
#  ('ARRONCHES',),
#  ('PONTE DE SOR',),
#  ('CARTAXO',),
#  ('SANTARÉM',),
#  ('LOURINHÃ',),
#  ('PONTE DE SOR',),
#  ('ALCOCHETE',),
#  ('OEIRAS',),
#  ('ARRAIOLOS',),
#  ('OEIRAS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('MONTEMOR-O-NOVO',),
#  ('VILA VIÇOSA',),
#  ('CASCAIS',),
#  ('PONTE DE SOR',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('VENDAS NOVAS',),
#  ('AMADORA',),
#  ('REDONDO',),
#  ('SINTRA',),
#  ('AMADORA',),
#  ('LISBOA',),
#  ('AVIS',),
#  ('TORRES VEDRAS',),
#  ('LOURINHÃ',),
#  ('LOURINHÃ',),
#  ('ALTER DO CHÃO',),
#  ('LISBOA',),
#  ('LOURES',),
#  ('ALMEIRIM',),
#  ('AZAMBUJA',),
#  ('LOURINHÃ',),
#  ('AZAMBUJA',),
#  ('CADAVAL',),
#  ('CADAVAL',),
#  ('ALTER DO CHÃO',),
#  ('LOURINHÃ',),
#  ('SANTARÉM',),
#  ('RIO MAIOR',),
#  ('PORTALEGRE',),
#  ('RIO MAIOR',),
#  ('CADAVAL',),
#  ('SANTARÉM',),
#  ('ALTER DO CHÃO',),
#  ('BOMBARRAL',),
#  ('SINTRA',),
#  ('ESTREMOZ',),
#  ('PORTALEGRE',),
#  ('LOURINHÃ',),
#  ('CADAVAL',),
#  ('CADAVAL',),
#  ('SANTARÉM',),
#  ('MÊDA',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('AMADORA',),
#  ('SINTRA',),
#  ('ODIVELAS',),
#  ('SANTA MARIA DA FEIRA',),
#  ('LOURES',),
#  ('BORBA',),
#  ('ODIVELAS',),
#  ('ODIVELAS',),
#  ('VILA VIÇOSA',),
#  ('SINTRA',),
#  ('BORBA',),
#  ('SINTRA',),
#  ('ARRAIOLOS',),
#  ('ALCOCHETE',),
#  ('MONTEMOR-O-NOVO',),
#  ('ESTREMOZ',),
#  ('SINTRA',),
#  ('ODIVELAS',),
#  ('LOURES',),
#  ('LOURES',),
#  ('SINTRA',),
#  ('ARRAIOLOS',),
#  ('MONTIJO',),
#  ('VILA FRANCA DE XIRA',),
#  ('CORUCHE',),
#  ('ESTREMOZ',),
#  ('LOURES',),
#  ('ESTREMOZ',),
#  ('SINTRA',),
#  ('ELVAS',),
#  ('VILA FRANCA DE XIRA',),
#  ('MORA',),
#  ('LOURES',),
#  ('CORUCHE',),
#  ('LOURES',),
#  ('BENAVENTE',),
#  ('ARRAIOLOS',),
#  ('BORBA',),
#  ('ELVAS',),
#  ('SINTRA',),
#  ('ESTREMOZ',),
#  ('VILA FRANCA DE XIRA',),
#  ('LOURES',),
#  ('ESTREMOZ',),
#  ('MAFRA',),
#  ('MAFRA',),
#  ('BENAVENTE',),
#  ('VILA FRANCA DE XIRA',),
#  ('ARRUDA DOS VINHOS',),
#  ('ARRUDA DOS VINHOS',),
#  ('MAFRA',),
#  ('ELVAS',),
#  ('SOBRAL DE MONTE AGRAÇO',),
#  ('ELVAS',),
#  ('ARRUDA DOS VINHOS',),
#  ('ESTREMOZ',),
#  ('MAFRA',),
#  ('SOUSEL',),
#  ('SOUSEL',),
#  ('MORA',),
#  ('SANTARÉM',),
#  ('SANTA MARIA DA FEIRA',),
#  ('AROUCA',),
#  ('SERNANCELHE',),
#  ('SANTA MARIA DA FEIRA',),
#  ('SANTA MARIA DA FEIRA',),
#  ('SANTA MARIA DA FEIRA',),
#  ('MOIMENTA DA BEIRA',),
#  ('CASTRO DAIRE',),
#  ('FIGUEIRA DE CASTELO RODRIGO',),
#  ('CELORICO DA BEIRA',),
#  ('CASTRO DAIRE',),
#  ('AROUCA',),
#  ('MOIMENTA DA BEIRA',),
#  ('VILA VERDE',),
#  ('PENEDONO',),
#  ('AROUCA',),
#  ('CASTRO DAIRE',),
#  ('SANTA MARIA DA FEIRA',),
#  ('PINHEL',),
#  ('IDANHA-A-NOVA',),
#  ('OVAR',),
#  ('CASTRO DAIRE',),
#  ('CASTRO DAIRE',),
#  ('SANTA MARIA DA FEIRA',),
#  ('CASTRO DAIRE',),
#  ('MÊDA',),
#  ('OLEIROS',),
#  ('SOURE',),
#  ('OLEIROS',),
#  ('CASTELO BRANCO',),
#  ('IDANHA-A-NOVA',),
#  ('CASTELO BRANCO',),
#  ('ANSIÃO',),
#  ('PENEDONO',),
#  ('PAMPILHOSA DA SERRA',),
#  ('OLEIROS',),
#  ('MOIMENTA DA BEIRA',),
#  ('AROUCA',),
#  ('OLEIROS',),
#  ('PEDRÓGÃO GRANDE',),
#  ('PENELA',),
#  ('POMBAL',),
#  ('POMBAL',),
#  ('SOURE',),
#  ('AVEIRO',),
#  ('SERNANCELHE',),
#  ('ESPINHO',),
#  ('SANTA MARIA DA FEIRA',),
#  ('CASTRO DAIRE',),
#  ('FIGUEIRA DE CASTELO RODRIGO',),
#  ('SANTA MARIA DA FEIRA',),
#  ('MOIMENTA DA BEIRA',),
#  ('AROUCA',),
#  ('CASTRO DAIRE',),
#  ('RESENDE',),
#  ('CINFÃES',),
#  ('TABUAÇO',),
#  ('TAROUCA',),
#  ('VILA NOVA DE GAIA',),
#  ('PENEDONO',),
#  ('GONDOMAR',),
#  ('VILA NOVA DE GAIA',),
#  ('ALPIARÇA',),
#  ('CASTELO BRANCO',),
#  ('PEDRÓGÃO GRANDE',),
#  ('CASTELO BRANCO',),
#  ('LEIRIA',),
#  ('OLEIROS',),
#  ('ANSIÃO',),
#  ('IDANHA-A-NOVA',),
#  ('POMBAL',),
#  ('CASTELO BRANCO',),
#  ('ANSIÃO',),
#  ...]
